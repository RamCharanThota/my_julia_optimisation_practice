# %%
#variable names
e =2345
# Out:
# 2345

# %%
π=3.145
# Out:
# 3.145

# %%
# some reserved words if you use reserved it will throws an error
 struct = 3
# Out:
# syntax: unexpected "="
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/all_about_robotics/julia_optimisation_course/tutorial/julia_tutorial1.ipynb:2

# %%
#arthematic operators
x=4
p=5

y=((x+2)^2-4)/(x-2)^(p-2)
typeof(y) # it gives us flaot value

# if you want to get integer division
y=((x+2)^2-4)÷(x-2)^(p-2)
typeof(y) # it gives us flaot value
# Out:
# Int64

# %%
# promotion system
x=1.0 # Float64
y=2   # Int64

xp,yp=promote(x,y)

promote(1, 2f0, true, 4.5, Int32(1))
    
#exercise
x = 1
y = 1f0
z = true
w = Int32(1)

promote(x,y,z,x)
# Out:
# (1.0f0, 1.0f0, 1.0f0, 1.0f0)

# %%
#compare number of special values
isequal(NaN,NaN)
!isequal(NaN, NaN)
# Out:
# false

# %%
#rounding functions
x=3141.5926

@show round(x)
@show floor(x)
@show ceil(x)
@show trunc(x)

# we can specify the output type
round(Int64, x)
floor(Int32, x)
ceil(Int16, x)
# Out:
# round(x) = 3142.0
# floor(x) = 3141.0
# ceil(x) = 3142.0
# trunc(x) = 3141.0
# 3142

# %%
# strings
str="hello world"
str1 = "This is how a string is created: \"string\"."
 str2="The \$ will be fine."
# Out:
# "The \$ will be fine."

# %%
 mstr = """
       This is how a 
       string is created: "string".
       """
print(mstr)
# Out:
# This is how a
# string is created: "string".
